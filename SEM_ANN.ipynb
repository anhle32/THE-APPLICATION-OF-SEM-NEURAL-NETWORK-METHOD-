# %% [markdown]
# # 1. Nhập thư viện

# %%
import semopy
import pandas as pd
import seaborn as sns
import numpy as np
import psython as psy
import pingouin as pg

# %% [markdown]
# # 2. Khai báo dữ liệu

# %%
data=pd.read_csv('datafinal.csv')

# %%
data.head()
# Out:
#    DSD1  DSD2  DSD3  DSD4   DSD  HI1  HI2  HI3  HI4    HI  ...    XH  YD1  \
# 0     3     3     4     4  3.50    3    4    4    3  3.50  ...  2.50    4
# 1     2     2     2     3  2.25    2    3    3    2  2.50  ...  2.50    3
# 2     2     3     3     2  2.50    1    2    2    3  2.00  ...  3.00    2
# 3     3     4     4     3  3.50    2    2    3    3  2.50  ...  2.25    2
# 4     3     4     3     3  3.25    2    2    3    2  2.25  ...  4.50    4
#
#    YD2  YD3  YD4    YD  LC1  LC2  LC3        LC
# 0    4    4    3  3.75    3    4    4  3.666667
# 1    2    2    3  2.50    3    3    3  3.000000
# 2    1    2    3  2.00    2    1    2  1.666667
# 3    3    3    2  2.50    2    2    3  2.333333
# 4    3    3    4  3.50    3    3    3  3.000000
#
# [5 rows x 39 columns]

# %%
data.tail()
# Out:
#      DSD1  DSD2  DSD3  DSD4   DSD  HI1  HI2  HI3  HI4    HI  ...    XH  YD1  \
# 438     3     4     4     3  3.50    2    2    3    4  2.75  ...  3.25    4
# 439     4     3     4     3  3.50    3    3    3    3  3.00  ...  3.75    4
# 440     4     4     4     4  4.00    4    3    4    4  3.75  ...  4.00    4
# 441     4     3     4     4  3.75    3    3    3    4  3.25  ...  4.00    3
# 442     3     4     4     3  3.50    2    1    3    2  2.00  ...  2.50    4
#
#      YD2  YD3  YD4    YD  LC1  LC2  LC3        LC
# 438    4    4    5  4.25    3    3    3  3.000000
# 439    3    3    3  3.25    4    4    3  3.666667
# 440    5    4    5  4.50    4    4    4  4.000000
# 441    4    3    4  3.50    3    3    3  3.000000
# 442    3    4    3  3.50    3    3    3  3.000000
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Các thang đo trong mô hình
# ![figure1.png](attachment:figure1.png)

# %%
DSD_scale=data[['DSD1','DSD2','DSD3','DSD4']]
HI_scale=data[['HI1','HI2','HI3','HI4']]
RR_scale=data[['RR1','RR2','RR3','RR4']]
HA_scale=data[['HA1','HA2','HA3','HA4']]
XH_scale=data[['XH1','XH2','XH3','XH4']]
CP_scale=data[['CP1','CP2','CP3','CP4']]
YD_scale=data[['YD1','YD2','YD3','YD4']]
LC_scale=data[['LC1','LC2','LC3']]

# %% [markdown]
# # 3. Ma trận tương quan giữa các biến trong mô hình

# %%
data1=pd.concat([DSD_scale,HI_scale,RR_scale,HA_scale,CP_scale,XH_scale,YD_scale,LC_scale], axis=1)

# %%
sns.set(rc={'figure.figsize':(20,15)})
sns.heatmap(data1.corr(),annot=True, cmap='BrBG')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 4. Đánh giá độ tin cậy của thang đo

# %% [markdown]
# ![figure2.png](attachment:figure2.png)

# %%
DSD_sca=psy.cronbach_alpha_scale_if_deleted(DSD_scale)
DSD_sca[0]
# Out:
# (0.7967623656816869, array([0.764, 0.826]))

# %%
psy.cronbach_alpha_scale_if_deleted(HI_scale)
# Out:
# [(0.8271223275350087, array([0.799, 0.852])),
#    Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  HI1                    9.489842                        3.064942
#  1  HI2                    9.345372                        2.964158
#  2  HI3                    8.862302                        2.797739
#  3  HI4                    8.762980                        2.864509
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.636839                          0.789624
#  1                          0.649449                          0.783567
#  2                          0.707490                          0.756410
#  3                          0.622558                          0.797443  ]

# %%
psy.cronbach_alpha_scale_if_deleted(RR_scale)
# Out:
# [(0.8378581456636167, array([0.812, 0.861])),
#    Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  RR1                    8.331828                        3.036700
#  1  RR2                    7.853273                        3.220504
#  2  RR3                    8.277652                        3.087893
#  3  RR4                    8.415350                        3.152886
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.637160                          0.811559
#  1                          0.651143                          0.802872
#  2                          0.709515                          0.777448
#  3                          0.686433                          0.787790  ]

# %%
psy.cronbach_alpha_scale_if_deleted(HA_scale)
# Out:
# [(0.8327751486683642, array([0.806, 0.857])),
#    Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  HA1                   10.194131                        3.351368
#  1  HA2                   10.212190                        3.484285
#  2  HA3                   10.234763                        3.397250
#  3  HA4                   10.248307                        3.553589
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.637806                          0.801150
#  1                          0.659597                          0.789654
#  2                          0.668629                          0.785567
#  3                          0.686761                          0.779428  ]

# %%
psy.cronbach_alpha_scale_if_deleted(CP_scale)
# Out:
# [(0.8848028379928807, array([0.866, 0.901])),
#    Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  CP1                   10.146727                        4.320051
#  1  CP2                   10.162528                        4.217869
#  2  CP3                   10.137698                        3.987784
#  3  CP4                   10.158014                        3.830179
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.630998                          0.896951
#  1                          0.710065                          0.866512
#  2                          0.805082                          0.830414
#  3                          0.859994                          0.808150  ]

# %%
psy.cronbach_alpha_scale_if_deleted(XH_scale)
# Out:
# [(0.8122490560022317, array([0.782, 0.839])),
#    Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  XH1                   10.024831                        3.322911
#  1  XH2                    9.963883                        3.324484
#  2  XH3                    9.975169                        3.327436
#  3  XH4                   10.133183                        3.097607
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.641479                          0.759593
#  1                          0.620322                          0.769077
#  2                          0.599546                          0.778866
#  3                          0.662048                          0.749038  ]

# %%
psy.cronbach_alpha_scale_if_deleted(YD_scale)
# Out:
# [(0.8551226220703898, array([0.832, 0.876])),
#    Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  YD1                   10.218962                        4.171404
#  1  YD2                   10.173815                        4.428996
#  2  YD3                   10.239278                        4.263884
#  3  YD4                   10.162528                        4.385290
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.739015                          0.797849
#  1                          0.664048                          0.829436
#  2                          0.751453                          0.793692
#  3                          0.640004                          0.840320  ]

# %%
psy.cronbach_alpha_scale_if_deleted(LC_scale)
# Out:
# [(0.8472303234761247, array([0.821, 0.87 ])),
#    Item  Scale Mean if Item Deleted  Scale Variance if Item Deleted  \
#  0  LC1                    6.805869                        2.183947
#  1  LC2                    6.744921                        1.887276
#  2  LC3                    6.787810                        2.086095
#
#     Corrected Item-Total Correlation  Cronbach's Alpha if Item Deleted
#  0                          0.687186                          0.813339
#  1                          0.770396                          0.731645
#  2                          0.690881                          0.809822  ]

# %% [markdown]
# # 5. Phân tích nhân tố
# ![f2.png](attachment:f2.png)

# %%
from factor_analyzer import (FactorAnalyzer,ConfirmatoryFactorAnalyzer,ModelSpecificationParser)
import matplotlib.pyplot as plt

# %%
data1=pd.concat([DSD_scale,HI_scale,RR_scale,HA_scale,CP_scale,XH_scale], axis=1)

# %%
data1.head()
# Out:
#    DSD1  DSD2  DSD3  DSD4  HI1  HI2  HI3  HI4  RR1  RR2  ...  HA3  HA4  CP1  \
# 0     3     3     4     4    3    4    4    3    2    3  ...    4    4    4
# 1     2     2     2     3    2    3    3    2    3    4  ...    3    4    2
# 2     2     3     3     2    1    2    2    3    3    4  ...    3    3    3
# 3     3     4     4     3    2    2    3    3    3    3  ...    3    5    2
# 4     3     4     3     3    2    2    3    2    2    3  ...    3    3    3
#
#    CP2  CP3  CP4  XH1  XH2  XH3  XH4
# 0    5    5    5    3    3    2    2
# 1    2    2    2    3    3    2    2
# 2    3    3    3    3    3    3    3
# 3    3    2    3    2    2    3    2
# 4    3    4    3    5    5    4    4
#
# [5 rows x 24 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DSD1    443 non-null    int64
#  1   DSD2    443 non-null    int64
#  2   DSD3    443 non-null    int64
#  3   DSD4    443 non-null    int64
#  4   HI1     443 non-null    int64
#  5   HI2     443 non-null    int64
#  6   HI3     443 non-null    int64
#  7   HI4     443 non-null    int64
#  8   RR1     443 non-null    int64
#  9   RR2     443 non-null    int64
#  10  RR3     443 non-null    int64
#  11  RR4     443 non-null    int64
#  12  HA1     443 non-null    int64
#  13  HA2     443 non-null    int64
#  14  HA3     443 non-null    int64
#  15  HA4     443 non-null    int64
#  16  CP1     443 non-null    int64
#  17  CP2     443 non-null    int64
#  18  CP3     443 non-null    int64
#  19  CP4     443 non-null    int64
#  20  XH1     443 non-null    int64
#  21  XH2     443 non-null    int64
# ...

# %%
fa=FactorAnalyzer(n_factors=6,rotation='promax')

# %%
fa.fit(data1)
# Out:
# FactorAnalyzer(n_factors=6, rotation_kwargs={})

# %%
loadings= fa.loadings_
loadings
# Out:
# array([[ 0.00821741,  0.00619374,  0.04790553,  0.09631753,  0.03570229,
#          0.67807479],
#        [ 0.03412481,  0.00914254, -0.01579649, -0.02127027, -0.04576292,
#          0.68549277],
#        [-0.00883602, -0.00811256, -0.06849403, -0.11691899, -0.03251368,
#          0.68237871],
#        [-0.03952095, -0.02303696,  0.02152719,  0.06900688,  0.02230861,
#          0.78055052],
#        [-0.05071292,  0.02905926,  0.0214967 ,  0.71824758, -0.00179184,
#          0.05148712],
#        [ 0.05931507,  0.01488118,  0.06171614,  0.73121204, -0.01563372,
#         -0.02495153],
#        [-0.05253115,  0.02869511, -0.11033001,  0.84104474, -0.08066968,
#         -0.06996945],
#        [ 0.07061902, -0.08491221, -0.00781143,  0.66205821,  0.07579711,
#          0.04794942],
#        [-0.02314683, -0.01851593,  0.68435172,  0.01039985, -0.05539032,
#          0.0033765 ],
#        [ 0.0328041 , -0.06705921,  0.69447735, -0.06574289,  0.01367919,
#         -0.02881093],
# ...

# %%
ev,v=fa.get_eigenvalues()

# %%
xvals=range(1,data1.shape[1]+1)

# %%
plt.scatter(xvals,ev)
plt.plot(xvals,ev)
plt.title('Scree plot')
plt.xlabel('Factor')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

# %%
fa_loading=pd.DataFrame(loadings,index=['DSD1', 'DSD2', 'DSD3', 'DSD4', 'HI1', 'HI2', 'HI3', 'HI4', 'RR1', 'RR2', 'RR3', 'RR4', 'HA1', 'HA2', 'HA3', 'HA4', 'CP1', 'CP2', 'CP3', 'CP4', 'XH1', 'XH2', 'XH3', 'XH4'
])
fa_loading
# Out:
#              0         1         2         3         4         5
# DSD1  0.008217  0.006194  0.047906  0.096318  0.035702  0.678075
# DSD2  0.034125  0.009143 -0.015796 -0.021270 -0.045763  0.685493
# DSD3 -0.008836 -0.008113 -0.068494 -0.116919 -0.032514  0.682379
# DSD4 -0.039521 -0.023037  0.021527  0.069007  0.022309  0.780551
# HI1  -0.050713  0.029059  0.021497  0.718248 -0.001792  0.051487
# HI2   0.059315  0.014881  0.061716  0.731212 -0.015634 -0.024952
# HI3  -0.052531  0.028695 -0.110330  0.841045 -0.080670 -0.069969
# HI4   0.070619 -0.084912 -0.007811  0.662058  0.075797  0.047949
# RR1  -0.023147 -0.018516  0.684352  0.010400 -0.055390  0.003376
# RR2   0.032804 -0.067059  0.694477 -0.065743  0.013679 -0.028811
# RR3  -0.025145  0.069760  0.815790  0.008142 -0.022910 -0.019914
# RR4  -0.017026 -0.006266  0.777525  0.019983  0.043187  0.018006
# HA1   0.023910  0.697412  0.017730  0.023309  0.034122 -0.007487
# ...

# %%
data_loading=fa_loading.apply(lambda x: (np.where(x< 0.5,'',x)))
data_loading
# Out:
#                        0                   1                   2  \
# DSD1
# DSD2
# DSD3
# DSD4
# HI1
# HI2
# HI3
# HI4
# RR1                                           0.6843517215779674
# RR2                                           0.6944773527380517
# RR3                                           0.8157897920903399
# RR4                                           0.7775251590062671
# HA1                       0.6974116523340821
# HA2                       0.7458433871722515
# HA3                       0.7349970383317899
# HA4                       0.8221579762969937
# CP1   0.5476166451305118
# CP2   0.7105985351511868
# CP3   0.8840744150959583
# CP4   1.0718041981274518
# XH1
# XH2
# XH3
# XH4
#
#                        3                   4                   5
# DSD1                                          0.6780747858531583
# DSD2                                          0.6854927704580623
# DSD3                                          0.6823787105886941
# ...

# %% [markdown]
# # 6. Phân tích nhân tố khẳng định

# %%
desc='''DSD=~DSD1+DSD2+DSD3+DSD4'''

# %%
desc+='\n HI=~HI1+HI2+HI3+HI4'

# %%
desc+='\n RR=~RR1+RR2+RR3+RR4'+'\n HA=~HA1+HA2+HA3+HA4'

# %%
desc+='\n CP=~CP1+CP2+CP3+CP4'+'\n XH=~XH1+XH2+XH3+XH4'

# %%
desc+='\n DSD~~HI'+'\n DSD~~RR'+'\n DSD~~HA'+'\n DSD~~CP'+'\n DSD~~XH'+'\n HI~~RR'+'\n HI~~HA'+'\n HI~~CP'+'\n HI~~XH'+'\n RR~~HA'+'\n RR~~CP'+'\n RR~~XH'+'\n HA~~CP'+'\n HA~~XH'+'\n CP~~XH'

# %%
print(desc)
# Out:
# DSD=~DSD1+DSD2+DSD3+DSD4
#  HI=~HI1+HI2+HI3+HI4
#  RR=~RR1+RR2+RR3+RR4
#  HA=~HA1+HA2+HA3+HA4
#  CP=~CP1+CP2+CP3+CP4
#  XH=~XH1+XH2+XH3+XH4
#  DSD~~HI
#  DSD~~RR
#  DSD~~HA
#  DSD~~CP
#  DSD~~XH
#  HI~~RR
#  HI~~HA
#  HI~~CP
#  HI~~XH
#  RR~~HA
#  RR~~CP
#  RR~~XH
#  HA~~CP
#  HA~~XH
#  CP~~XH

# %%
mod = semopy.Model(desc)

# %%
res = mod.fit(data)
print(res)
# Out:
# Name of objective: MLW
# Optimization method: SLSQP
# Optimization successful.
# Optimization terminated successfully
# Objective value: 1.234
# Number of iterations: 68
# Params: 1.076 0.988 1.253 1.063 1.203 1.112 0.930 1.022 0.970 0.954 0.999 0.927 1.151 1.366 1.478 0.948 0.942 1.104 0.046 -0.080 0.082 0.088 0.039 0.229 -0.074 0.084 0.105 0.062 0.212 -0.112 -0.119 -0.047 0.287 0.129 0.088 0.321 0.069 0.249 0.368 0.243 0.044 0.190 0.289 0.170 0.201 0.218 0.227 0.170 0.320 0.276 0.239 0.212 0.236 0.195 0.110 0.260 0.266 0.286 0.295 0.246 0.239 0.209 0.278

# %%
ins = mod.inspect()
print(ins)
# Out:
#     lval  op  rval  Estimate  Std. Err    z-value p-value
# 0   DSD1   ~   DSD  1.000000         -          -       -
# 1   DSD2   ~   DSD  1.076288   0.08763  12.282132     0.0
# 2   DSD3   ~   DSD  0.988198  0.085814  11.515623     0.0
# 3   DSD4   ~   DSD  1.253034  0.095197  13.162544     0.0
# 4    HI1   ~    HI  1.000000         -          -       -
# ..   ...  ..   ...       ...       ...        ...     ...
# 64  DSD2  ~~  DSD2  0.285993   0.02476  11.550823     0.0
# 65   HA1  ~~   HA1  0.295186  0.024975  11.819109     0.0
# 66   XH4  ~~   XH4  0.245970   0.02418  10.172405     0.0
# 67   HA3  ~~   HA3  0.239352  0.021579  11.091736     0.0
# 68   HI2  ~~   HI2  0.208634  0.018095  11.529878     0.0
#
# [69 rows x 7 columns]

# %%
import os
os.environ['PATH'] += os.pathsep + 'C:/Program Files/Graphviz/bin'

# %%
from semopy import semplot
g = semplot(mod,filename="cfa.png")
g

# %%
stats = semopy.calc_stats(mod)

# %%
print(stats)
# Out:
#        DoF  DoF Baseline        chi2  chi2 p-value  chi2 Baseline      CFI  \
# Value  237           276  546.470818           0.0    5124.360153  0.93617
#
#             GFI     AGFI       NFI       TLI     RMSEA         AIC  \
# Value  0.893358  0.87581  0.893358  0.925666  0.054353  123.532863
#
#               BIC    LogLik
# Value  381.427759  1.233568

# %%
estimate_cfa=pd.DataFrame(ins)
estimate_cfa
# Out:
#     lval  op  rval  Estimate  Std. Err    z-value p-value
# 0   DSD1   ~   DSD  1.000000         -          -       -
# 1   DSD2   ~   DSD  1.076288   0.08763  12.282132     0.0
# 2   DSD3   ~   DSD  0.988198  0.085814  11.515623     0.0
# 3   DSD4   ~   DSD  1.253034  0.095197  13.162544     0.0
# 4    HI1   ~    HI  1.000000         -          -       -
# ..   ...  ..   ...       ...       ...        ...     ...
# 64  DSD2  ~~  DSD2  0.285993   0.02476  11.550823     0.0
# 65   HA1  ~~   HA1  0.295186  0.024975  11.819109     0.0
# 66   XH4  ~~   XH4  0.245970   0.02418  10.172405     0.0
# 67   HA3  ~~   HA3  0.239352  0.021579  11.091736     0.0
# 68   HI2  ~~   HI2  0.208634  0.018095  11.529878     0.0
#
# [69 rows x 7 columns]

# %%
ins1 = mod.inspect(std_est=True)
print(ins1)
# Out:
#     lval  op  rval  Estimate  Est. Std  Std. Err    z-value p-value
# 0   DSD1   ~   DSD  1.000000  0.708075         -          -       -
# 1   DSD2   ~   DSD  1.076288  0.693478   0.08763  12.282132     0.0
# 2   DSD3   ~   DSD  0.988198  0.641108  0.085814  11.515623     0.0
# 3   DSD4   ~   DSD  1.253034  0.774706  0.095197  13.162544     0.0
# 4    HI1   ~    HI  1.000000  0.717110         -          -       -
# ..   ...  ..   ...       ...       ...       ...        ...     ...
# 64  DSD2  ~~  DSD2  0.285993  0.519088   0.02476  11.550823     0.0
# 65   HA1  ~~   HA1  0.295186  0.479283  0.024975  11.819109     0.0
# 66   XH4  ~~   XH4  0.245970  0.420649   0.02418  10.172405     0.0
# 67   HA3  ~~   HA3  0.239352  0.427821  0.021579  11.091736     0.0
# 68   HI2  ~~   HI2  0.208634  0.465184  0.018095  11.529878     0.0
#
# [69 rows x 8 columns]

# %%
estimate_cfa1=pd.DataFrame(ins1)
estimate_cfa1
# Out:
#     lval  op  rval  Estimate  Est. Std  Std. Err    z-value p-value
# 0   DSD1   ~   DSD  1.000000  0.708075         -          -       -
# 1   DSD2   ~   DSD  1.076288  0.693478   0.08763  12.282132     0.0
# 2   DSD3   ~   DSD  0.988198  0.641108  0.085814  11.515623     0.0
# 3   DSD4   ~   DSD  1.253034  0.774706  0.095197  13.162544     0.0
# 4    HI1   ~    HI  1.000000  0.717110         -          -       -
# ..   ...  ..   ...       ...       ...       ...        ...     ...
# 64  DSD2  ~~  DSD2  0.285993  0.519088   0.02476  11.550823     0.0
# 65   HA1  ~~   HA1  0.295186  0.479283  0.024975  11.819109     0.0
# 66   XH4  ~~   XH4  0.245970  0.420649   0.02418  10.172405     0.0
# 67   HA3  ~~   HA3  0.239352  0.427821  0.021579  11.091736     0.0
# 68   HI2  ~~   HI2  0.208634  0.465184  0.018095  11.529878     0.0
#
# [69 rows x 8 columns]

# %%
est_std=estimate_cfa1[['lval','rval','Est. Std']].loc[0:23]
est_std
# Out:
#     lval rval  Est. Std
# 0   DSD1  DSD  0.708075
# 1   DSD2  DSD  0.693478
# 2   DSD3  DSD  0.641108
# 3   DSD4  DSD  0.774706
# 4    HI1   HI  0.717110
# 5    HI2   HI  0.731311
# 6    HI3   HI  0.802399
# 7    HI4   HI  0.709081
# 8    RR1   RR  0.713790
# 9    RR2   RR  0.733961
# 10   RR3   RR  0.798502
# 11   RR4   RR  0.766263
# 12   HA1   HA  0.721607
# 13   HA2   HA  0.743966
# 14   HA3   HA  0.756425
# 15   HA4   HA  0.765304
# 16   CP1   CP  0.634879
# 17   CP2   CP  0.758440
# 18   CP3   CP  0.899125
# 19   CP4   CP  0.962116
# 20   XH1   XH  0.748935
# 21   XH2   XH  0.695702
# 22   XH3   XH  0.678326
# 23   XH4   XH  0.761151

# %%
est_std['lamda2']=est_std['Est. Std']*est_std['Est. Std']
est_std
# Out:
#     lval rval  Est. Std    lamda2
# 0   DSD1  DSD  0.708075  0.501371
# 1   DSD2  DSD  0.693478  0.480912
# 2   DSD3  DSD  0.641108  0.411019
# 3   DSD4  DSD  0.774706  0.600170
# 4    HI1   HI  0.717110  0.514247
# 5    HI2   HI  0.731311  0.534816
# 6    HI3   HI  0.802399  0.643845
# 7    HI4   HI  0.709081  0.502796
# 8    RR1   RR  0.713790  0.509496
# 9    RR2   RR  0.733961  0.538699
# 10   RR3   RR  0.798502  0.637605
# 11   RR4   RR  0.766263  0.587159
# 12   HA1   HA  0.721607  0.520717
# 13   HA2   HA  0.743966  0.553486
# 14   HA3   HA  0.756425  0.572179
# 15   HA4   HA  0.765304  0.585690
# 16   CP1   CP  0.634879  0.403072
# 17   CP2   CP  0.758440  0.575231
# 18   CP3   CP  0.899125  0.808426
# 19   CP4   CP  0.962116  0.925668
# 20   XH1   XH  0.748935  0.560903
# 21   XH2   XH  0.695702  0.484001
# 22   XH3   XH  0.678326  0.460126
# 23   XH4   XH  0.761151  0.579351

# %%
est_std['1-lamda2']=1-est_std['lamda2']
est_std
# Out:
#     lval rval  Est. Std    lamda2  1-lamda2
# 0   DSD1  DSD  0.708075  0.501371  0.498629
# 1   DSD2  DSD  0.693478  0.480912  0.519088
# 2   DSD3  DSD  0.641108  0.411019  0.588981
# 3   DSD4  DSD  0.774706  0.600170  0.399830
# 4    HI1   HI  0.717110  0.514247  0.485753
# 5    HI2   HI  0.731311  0.534816  0.465184
# 6    HI3   HI  0.802399  0.643845  0.356155
# 7    HI4   HI  0.709081  0.502796  0.497204
# 8    RR1   RR  0.713790  0.509496  0.490504
# 9    RR2   RR  0.733961  0.538699  0.461301
# 10   RR3   RR  0.798502  0.637605  0.362395
# 11   RR4   RR  0.766263  0.587159  0.412841
# 12   HA1   HA  0.721607  0.520717  0.479283
# 13   HA2   HA  0.743966  0.553486  0.446514
# 14   HA3   HA  0.756425  0.572179  0.427821
# 15   HA4   HA  0.765304  0.585690  0.414310
# 16   CP1   CP  0.634879  0.403072  0.596928
# 17   CP2   CP  0.758440  0.575231  0.424769
# 18   CP3   CP  0.899125  0.808426  0.191574
# 19   CP4   CP  0.962116  0.925668  0.074332
# ...

# %%
lamda_DSD=est_std[est_std['rval']=='DSD']['Est. Std'].sum()
lamda_DSD
# Out:
# 2.8173674193053246

# %%
CR_DSD=(lamda_DSD*lamda_DSD)/((lamda_DSD*lamda_DSD)+est_std[est_std['rval']=='DSD']['1-lamda2'].sum())
CR_DSD
# Out:
# 0.7982189464144284

# %%
AVE_DSD=est_std[est_std['rval']=='DSD']['lamda2'].sum()/(est_std[est_std['rval']=='DSD']['lamda2'].sum()+est_std[est_std['rval']=='DSD']['1-lamda2'].sum())
AVE_DSD
# Out:
# 0.4983678787326622

# %%
lamda_HI=est_std[est_std['rval']=='HI']['Est. Std'].sum()
lamda_HI
# Out:
# 2.959901875095623

# %%
CR_HI=(lamda_HI*lamda_HI)/((lamda_HI*lamda_HI)+est_std[est_std['rval']=='HI']['1-lamda2'].sum())
CR_HI
# Out:
# 0.829224582186341

# %%
AVE_HI=est_std[est_std['rval']=='HI']['lamda2'].sum()/(est_std[est_std['rval']=='HI']['lamda2'].sum()+est_std[est_std['rval']=='HI']['1-lamda2'].sum())
AVE_HI
# Out:
# 0.5489259691650348

# %%
lamda_RR=est_std[est_std['rval']=='RR']['Est. Std'].sum()
lamda_RR
# Out:
# 3.012515310284446

# %%
CR_RR=(lamda_RR*lamda_RR)/((lamda_RR*lamda_RR)+est_std[est_std['rval']=='RR']['1-lamda2'].sum())
CR_RR
# Out:
# 0.8401226354986442

# %%
AVE_RR=est_std[est_std['rval']=='RR']['lamda2'].sum()/(est_std[est_std['rval']=='RR']['lamda2'].sum()+est_std[est_std['rval']=='RR']['1-lamda2'].sum())
AVE_RR
# Out:
# 0.5682395788961023

# %%
lamda_HA=est_std[est_std['rval']=='HA']['Est. Std'].sum()
lamda_HA
# Out:
# 2.9873028051550077

# %%
CR_HA=(lamda_HA*lamda_HA)/((lamda_HA*lamda_HA)+est_std[est_std['rval']=='HA']['1-lamda2'].sum())
CR_HA
# Out:
# 0.8346480256779236

# %%
AVE_HA=est_std[est_std['rval']=='HA']['lamda2'].sum()/(est_std[est_std['rval']=='HA']['lamda2'].sum()+est_std[est_std['rval']=='HA']['1-lamda2'].sum())
AVE_HA
# Out:
# 0.5580180675189119

# %%
lamda_CP=est_std[est_std['rval']=='CP']['Est. Std'].sum()
lamda_CP
# Out:
# 3.254560685349493

# %%
CR_CP=(lamda_CP*lamda_CP)/((lamda_CP*lamda_CP)+est_std[est_std['rval']=='CP']['1-lamda2'].sum())
CR_CP
# Out:
# 0.8916137696183638

# %%
AVE_CP=est_std[est_std['rval']=='CP']['lamda2'].sum()/(est_std[est_std['rval']=='CP']['lamda2'].sum()+est_std[est_std['rval']=='CP']['1-lamda2'].sum())
AVE_CP
# Out:
# 0.6780991661840086

# %%
lamda_XH=est_std[est_std['rval']=='XH']['Est. Std'].sum()
lamda_XH
# Out:
# 2.884113275829731

# %%
CR_XH=(lamda_XH*lamda_XH)/((lamda_XH*lamda_XH)+est_std[est_std['rval']=='XH']['1-lamda2'].sum())
CR_XH
# Out:
# 0.8128131790403759

# %%
AVE_XH=est_std[est_std['rval']=='XH']['lamda2'].sum()/(est_std[est_std['rval']=='XH']['lamda2'].sum()+est_std[est_std['rval']=='XH']['1-lamda2'].sum())
AVE_XH
# Out:
# 0.5210952243238103

# %% [markdown]
# # 7. Phân tích mô hình cấu trúc tuyến tính

# %%
desc+='\n YD=~YD1+YD2+YD3+YD4'+'\n LC=~LC1+LC2+LC3'+'\n LC~YD'+'\n YD~DSD+HI+RR+HA+CP+XH'
print(desc)
# Out:
# DSD=~DSD1+DSD2+DSD3+DSD4
#  HI=~HI1+HI2+HI3+HI4
#  RR=~RR1+RR2+RR3+RR4
#  HA=~HA1+HA2+HA3+HA4
#  CP=~CP1+CP2+CP3+CP4
#  XH=~XH1+XH2+XH3+XH4
#  DSD~~HI
#  DSD~~RR
#  DSD~~HA
#  DSD~~CP
#  DSD~~XH
#  HI~~RR
#  HI~~HA
#  HI~~CP
#  HI~~XH
#  RR~~HA
#  RR~~CP
#  RR~~XH
#  HA~~CP
#  HA~~XH
#  CP~~XH
#  YD=~YD1+YD2+YD3+YD4
#  LC=~LC1+LC2+LC3
#  LC~YD
#  YD~DSD+HI+RR+HA+CP+XH

# %%
mod = semopy.Model(desc)

# %%
res = mod.fit(data)
print(res)
# Out:
# Name of objective: MLW
# Optimization method: SLSQP
# Optimization successful.
# Optimization terminated successfully
# Objective value: 2.033
# Number of iterations: 72
# Params: 1.059 0.959 1.227 1.053 1.197 1.108 0.949 1.012 0.982 0.962 0.999 0.949 1.142 1.359 1.465 0.946 0.920 1.080 0.882 0.971 0.915 1.178 1.049 0.047 -0.081 0.083 0.091 0.040 0.236 -0.074 0.084 0.107 0.063 0.214 -0.111 -0.120 -0.048 0.284 0.129 0.088 0.315 0.070 0.252 0.181 0.187 0.332 0.179 0.198 0.211 0.220 0.326 0.243 0.205 0.238 0.187 0.219 0.238 0.261 0.306 0.300 0.245 0.111 0.365 0.244 0.046 0.295 0.170 0.280 0.069 0.236 0.108 0.259 0.286 0.208 0.253 0.211 0.284 0.810 0.318 0.378 -0.267 0.242 0.272 0.221

# %%
sem = mod.inspect()
print(sem)
# Out:
#     lval  op  rval  Estimate  Std. Err    z-value   p-value
# 0     LC   ~    YD  0.809830  0.050393  16.070424       0.0
# 1     YD   ~   DSD  0.317890  0.056715   5.605017       0.0
# 2     YD   ~    HI  0.377995  0.061957   6.100906       0.0
# 3     YD   ~    RR -0.266921   0.05295   -5.04103       0.0
# 4     YD   ~    HA  0.241644  0.051511   4.691141  0.000003
# ..   ...  ..   ...       ...       ...        ...       ...
# 87   HI4  ~~   HI4  0.259459  0.021515  12.059399       0.0
# 88  DSD2  ~~  DSD2  0.286167  0.024482   11.68889       0.0
# 89   YD3  ~~   YD3  0.208432  0.017313  12.039053       0.0
# 90   XH4  ~~   XH4  0.253157  0.024097  10.505585       0.0
# 91   HI2  ~~   HI2  0.210949  0.017976  11.734829       0.0
#
# [92 rows x 7 columns]

# %%
SEM=pd.DataFrame(sem)
SEM.head(7)
# Out:
#   lval op rval  Estimate  Std. Err    z-value   p-value
# 0   LC  ~   YD  0.809830  0.050393  16.070424       0.0
# 1   YD  ~  DSD  0.317890  0.056715   5.605017       0.0
# 2   YD  ~   HI  0.377995  0.061957   6.100906       0.0
# 3   YD  ~   RR -0.266921   0.05295   -5.04103       0.0
# 4   YD  ~   HA  0.241644  0.051511   4.691141  0.000003
# 5   YD  ~   CP  0.272010  0.060021   4.531921  0.000006
# 6   YD  ~   XH  0.221055  0.047972   4.607993  0.000004

# %%
g1 = semplot(mod,filename="sem.png")
g1

# %%
stats1 = semopy.calc_stats(mod)

# %%
print(stats1.T)
# Out:
#                      Value
# DoF             412.000000
# DoF Baseline    465.000000
# chi2            900.747610
# chi2 p-value      0.000000
# chi2 Baseline  7601.735880
# CFI               0.931517
# GFI               0.881508
# AGFI              0.866265
# NFI               0.881508
# TLI               0.922707
# RMSEA             0.051806
# AIC             163.933419
# BIC             507.793280
# LogLik            2.033290

# %% [markdown]
# # 8. Phân tích ANN

# %%
import VisualizeNN as VisNN
from sklearn.neural_network import MLPRegressor
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt

# %%
X=data[['DSD','HI','RR','HA','CP','XH']]
y = data['YD']

# %%
X
# Out:
#       DSD    HI    RR    HA    CP    XH
# 0    3.50  3.50  2.25  3.75  4.75  2.50
# 1    2.25  2.50  3.50  3.25  2.00  2.50
# 2    2.50  2.00  3.25  3.25  3.00  3.00
# 3    3.50  2.50  3.00  4.00  2.50  2.25
# 4    3.25  2.25  2.50  3.25  3.25  4.50
# ..    ...   ...   ...   ...   ...   ...
# 438  3.50  2.75  2.75  3.00  3.00  3.25
# 439  3.50  3.00  2.75  4.00  3.50  3.75
# 440  4.00  3.75  2.25  3.75  3.50  4.00
# 441  3.75  3.25  2.75  3.75  3.50  4.00
# 442  3.50  2.00  2.50  2.75  3.00  2.50
#
# [443 rows x 6 columns]

# %%
y
# Out:
# 0      3.75
# 1      2.50
# 2      2.00
# 3      2.50
# 4      3.50
#        ...
# 438    4.25
# 439    3.25
# 440    4.50
# 441    3.50
# 442    3.50
# Name: YD, Length: 443, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y.values,random_state=1, test_size=0.2)

# %%
X_train
# Out:
#       DSD    HI    RR    HA    CP    XH
# 439  3.50  3.00  2.75  4.00  3.50  3.75
# 165  4.50  2.50  2.75  3.75  4.00  3.50
# 80   2.75  3.25  3.00  2.75  4.25  4.00
# 46   2.75  3.25  3.00  2.75  2.50  2.25
# 372  2.75  2.50  3.50  4.25  3.00  2.75
# ..    ...   ...   ...   ...   ...   ...
# 255  3.50  2.50  2.25  3.25  3.25  3.00
# 72   3.00  3.50  2.75  4.50  3.25  3.50
# 396  3.25  3.00  3.00  4.25  3.75  4.00
# 235  3.75  3.50  3.75  3.00  3.50  3.25
# 37   3.50  2.50  3.00  2.25  3.25  3.50
#
# [354 rows x 6 columns]

# %%
X_test
# Out:
#       DSD    HI    RR    HA    CP    XH
# 247  2.75  3.25  2.50  4.50  3.00  3.50
# 179  2.75  3.50  2.50  3.00  3.25  3.00
# 186  2.75  3.75  3.25  3.25  4.50  2.50
# 31   2.50  2.00  3.25  3.00  3.00  2.50
# 218  3.50  2.75  2.50  2.25  3.25  4.25
# ..    ...   ...   ...   ...   ...   ...
# 272  3.25  2.75  2.75  4.25  3.00  2.75
# 213  4.00  2.75  2.00  3.25  3.25  4.00
# 303  3.50  3.25  2.00  4.25  3.75  4.00
# 287  3.50  3.25  2.00  4.25  3.50  4.00
# 257  4.00  3.75  2.25  3.75  3.50  4.00
#
# [89 rows x 6 columns]

# %%
sc_X = StandardScaler()
X_trainscaled=sc_X.fit_transform(X_train)
X_testscaled=sc_X.transform(X_test)

# %% [markdown]
# # 5.1. Cấu trúc mạng ANN theo Fang và Ma (2009)
# ![1.png](attachment:1.png)

# %%
regr = MLPRegressor(hidden_layer_sizes=(3,),random_state=1, max_iter=500).fit(X_trainscaled, y_train)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
network_structure = np.hstack(([X_trainscaled.shape[1]], np.asarray(regr.hidden_layer_sizes), [1]))

# %%
network=VisNN.DrawNN(network_structure, regr.coefs_)
network.draw()

# %%
regr.coefs_
# Out:
# [array([[ 0.47435216,  0.18982771, -0.1958033 ],
#         [-0.0299719 , -0.16662007,  0.14544992],
#         [-0.57487481, -0.26683654,  0.2151541 ],
#         [ 0.27007399, -0.01243557, -0.02411054],
#         [ 0.0821337 ,  0.47047328,  0.15993358],
#         [ 0.39198598,  0.21954311, -0.13126722]]),
#  array([[ 1.07570673],
#         [-0.35729983],
#         [ 1.07332894]])]

# %%
y_pred = regr.predict(X_testscaled)
y_pred
# Out:
# array([3.20889898, 3.06861134, 3.88359451, 3.0873467 , 2.95626676,
#        4.02556751, 3.08695466, 2.5323573 , 3.26749132, 3.27313263,
#        2.70295118, 2.36245742, 3.20361396, 3.1498388 , 2.29103948,
#        3.55471787, 3.20095097, 3.6765489 , 4.57003647, 2.55295759,
#        2.55063403, 4.70673347, 3.72740139, 3.61477164, 3.73050269,
#        4.80015257, 3.33223698, 3.09828508, 3.50720403, 3.17380093,
#        3.61647554, 2.85313429, 2.73109515, 3.5280205 , 3.01662619,
#        4.25426329, 4.3081005 , 5.04325424, 2.94245246, 3.59903704,
#        2.5990808 , 3.97669396, 3.30825896, 2.8468047 , 3.20995495,
#        3.27316985, 4.0679088 , 2.77523691, 3.39814381, 3.20900556,
#        3.46771041, 3.20143013, 2.99661209, 3.11306642, 2.66035646,
#        3.56506003, 4.57093287, 2.93188634, 3.04837768, 3.91136414,
#        4.89472546, 2.48080846, 2.77216388, 3.1578532 , 3.04837768,
#        3.05157939, 3.08150365, 4.04567463, 3.99823083, 2.36245742,
# ...

# %% [markdown]
# # Độ chính xác của mô hình

# %%
y_test
# Out:
# array([3.75, 3.  , 4.  , 2.  , 4.5 , 4.25, 3.  , 3.  , 3.75, 3.5 , 3.25,
#        2.5 , 1.5 , 2.5 , 3.75, 4.  , 2.75, 4.25, 4.25, 4.25, 2.75, 4.25,
#        3.75, 4.25, 3.75, 3.75, 3.5 , 3.5 , 4.  , 4.  , 3.5 , 3.5 , 3.  ,
#        3.75, 3.  , 4.5 , 4.  , 4.5 , 2.75, 4.25, 2.5 , 3.5 , 3.5 , 2.  ,
#        3.25, 4.  , 3.5 , 4.5 , 2.5 , 3.75, 3.5 , 3.75, 3.25, 4.5 , 3.  ,
#        4.  , 3.75, 2.  , 3.75, 3.75, 4.5 , 2.25, 3.5 , 3.25, 3.75, 4.25,
#        3.  , 3.25, 3.75, 2.5 , 4.5 , 3.5 , 2.5 , 3.5 , 3.75, 3.5 , 2.5 ,
#        3.5 , 3.5 , 3.75, 4.5 , 2.5 , 1.5 , 4.25, 3.75, 3.75, 3.75, 3.75,
#        4.5 ])

# %%
df_temp = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df_temp.head()
# Out:
#    Actual  Predicted
# 0    3.75   3.208899
# 1    3.00   3.068611
# 2    4.00   3.883595
# 3    2.00   3.087347
# 4    4.50   2.956267

# %%
df_temp = df_temp.head(30)
df_temp.plot(kind='bar',figsize=(10,6))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.5264590205543241
# Mean Squared Error: 0.45448297032985846
# Root Mean Squared Error: 0.6741535213360963

# %% [markdown]
# # Tầm quan trọng của các biến

# %%
regr.coefs_[0]
# Out:
# array([[ 0.47435216,  0.18982771, -0.1958033 ],
#        [-0.0299719 , -0.16662007,  0.14544992],
#        [-0.57487481, -0.26683654,  0.2151541 ],
#        [ 0.27007399, -0.01243557, -0.02411054],
#        [ 0.0821337 ,  0.47047328,  0.15993358],
#        [ 0.39198598,  0.21954311, -0.13126722]])

# %%
regr.coefs_[1]
# Out:
# array([[ 1.07570673],
#        [-0.35729983],
#        [ 1.07332894]])

# %%
def garson(A, B):
    """
    Computes Garson's algorithm
    A = matrix of weights of input-hidden layer (rows=input & cols=hidden)
    B = vector of weights of hidden-output layer
    """
    B = np.diag(B)

    # connection weight through the different hidden node
    cw = np.dot(A, B)

    # weight through node (axis=0 is column; sum per input feature)
    cw_h = abs(cw).sum(axis=0)

    # relative contribution of input neuron to outgoing signal of each hidden neuron
    # sum to find relative contribution of input neuron
    rc = np.divide(abs(cw), abs(cw_h))
    rc = rc.sum(axis=1)

    # normalize to 100% for relative importance
    ri = rc / rc.sum()
    return(ri)

# %%
a_vector = np.reshape(regr.coefs_[1], -1)
a_vector
# Out:
# array([ 1.07570673, -0.35729983,  1.07332894])

# %%
garson(regr.coefs_[0], a_vector)
# Out:
# array([0.20931743, 0.10299093, 0.25445593, 0.06171832, 0.19446356,
#        0.17705382])

# %% [markdown]
# # 5.2. Cấu trúc mạng ANN theo Yao et al. (1999) và Panahian (2011)
# ![3.png](attachment:3.png)

# %%
regr1 = MLPRegressor(hidden_layer_sizes=(2,),random_state=1, max_iter=500).fit(X_trainscaled, y_train)
# Out:
# c:\users\dell\appdata\local\programs\python\python39\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
network_structure = np.hstack(([X_trainscaled.shape[1]], np.asarray(regr1.hidden_layer_sizes), [1]))

# %%
network=VisNN.DrawNN(network_structure, regr1.coefs_)
network.draw()

# %%
regr1.coefs_
# Out:
# [array([[ 0.26632035,  0.34174269],
#         [-0.43776438, -0.12542748],
#         [-0.52536993, -0.72585412],
#         [-0.09581295, -0.11722553],
#         [ 0.18666573,  0.50503946],
#         [ 0.27239916,  0.59204558]]),
#  array([[-1.09611214],
#         [ 1.12234696]])]

# %%
y_pred1 = regr1.predict(X_testscaled)
y_pred1
# Out:
# array([1.73237329, 1.63130059, 0.94556463, 0.51099592, 3.61342342,
#        3.69425362, 2.21564748, 2.22210348, 3.34464177, 3.37689041,
#        2.4034578 , 1.15987043, 0.51099592, 0.51099592, 1.11184727,
#        3.11704894, 0.51099592, 3.43937943, 4.94063884, 2.04370563,
#        0.66027113, 5.1743262 , 3.13692032, 3.79465927, 2.87760054,
#        5.49393664, 3.47024376, 2.80139455, 2.70673257, 2.65711657,
#        2.11891049, 1.54856898, 2.65535267, 2.62373938, 1.68081921,
#        3.96888396, 4.87951341, 5.34396095, 0.82853148, 3.68257257,
#        0.98955355, 3.27918381, 3.51532074, 0.51099592, 3.35346388,
#        2.87374116, 3.61232561, 2.15215927, 0.67171628, 2.04674551,
#        1.77046416, 1.03042273, 2.11935371, 1.23876049, 2.44493041,
#        3.30339062, 4.23468892, 0.61195533, 2.02711417, 3.76044961,
#        4.6890541 , 2.16580456, 0.99633121, 0.51099592, 2.02711417,
#        2.25588497, 0.52836261, 3.68831479, 4.17522354, 1.15987043,
# ...

# %% [markdown]
# # Độ chính xác của mô hình

# %%
df_temp = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred1})
df_temp.head()
# Out:
#    Actual  Predicted
# 0    3.75   1.732373
# 1    3.00   1.631301
# 2    4.00   0.945565
# 3    2.00   0.510996
# 4    4.50   3.613423

# %%
df_temp = df_temp.head(30)
df_temp.plot(kind='bar',figsize=(10,6))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred1))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred1))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred1)))
# Out:
# Mean Absolute Error: 1.2580111114215045
# Mean Squared Error: 2.2703297319098743
# Root Mean Squared Error: 1.5067613387361232

# %% [markdown]
# # Tầm quan trọng của các biến

# %%
regr1.coefs_[0]
# Out:
# array([[ 0.26632035,  0.34174269],
#        [-0.43776438, -0.12542748],
#        [-0.52536993, -0.72585412],
#        [-0.09581295, -0.11722553],
#        [ 0.18666573,  0.50503946],
#        [ 0.27239916,  0.59204558]])

# %%
regr1.coefs_[1]
# Out:
# array([[-1.09611214],
#        [ 1.12234696]])

# %%
a_vector1 = np.reshape(regr1.coefs_[1], -1)
a_vector1
# Out:
# array([-1.09611214,  1.12234696])

# %%
garson(regr.coefs_[0], a_vector1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17480/770850264.py in <module>
# ----> 1 garson(regr.coefs_[0], a_vector1)
#
# NameError: name 'garson' is not defined
